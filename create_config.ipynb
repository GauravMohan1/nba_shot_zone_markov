# %%
stats_dict = {
    'Atlanta Hawks': [
        {'Restricted Area': '66.7'}, {'In the Paint (Non-RA)': '41.7'},
        {'Mid-Range': '45.7'}, {'Left Corner 3': '36.1'},
        {'Right Corner 3': '37.0'}, {'Corner 3': '38.1'},
        {'Above the Break 3': '34.9'}
    ],
    'Boston Celtics': [
        {'Restricted Area': '68.9'}, {'In the Paint (Non-RA)': '44.7'},
        {'Mid-Range': '41.3'}, {'Left Corner 3': '39.6'},
        {'Right Corner 3': '41.3'}, {'Corner 3': '40.4'},
        {'Above the Break 3': '36.9'}
    ],
    'Brooklyn Nets': [
        {'Restricted Area': '66.7'}, {'In the Paint (Non-RA)': '46.2'},
        {'Mid-Range': '48.9'}, {'Left Corner 3': '39.6'},
        {'Right Corner 3': '39.4'}, {'Corner 3': '39.5'},
        {'Above the Break 3': '37.3'}
    ],
    'Charlotte Hornets': [
        {'Restricted Area': '64.5'}, {'In the Paint (Non-RA)': '38.9'},
        {'Mid-Range': '41.8'}, {'Left Corner 3': '33.8'},
        {'Right Corner 3': '36.5'}, {'Corner 3': '35.0'},
        {'Above the Break 3': '32.5'}
    ],
    'Chicago Bulls': [
        {'Restricted Area': '66.8'}, {'In the Paint (Non-RA)': '46.9'},
        {'Mid-Range': '44.5'}, {'Left Corner 3': '39.9'},
        {'Right Corner 3': '38.5'}, {'Corner 3': '39.3'},
        {'Above the Break 3': '34.9'}
    ],
    'Cleveland Cavaliers': [
        {'Restricted Area': '68.6'}, {'In the Paint (Non-RA)': '44.7'},
        {'Mid-Range': '39.8'}, {'Left Corner 3': '36.3'},
        {'Right Corner 3': '37.2'}, {'Corner 3': '36.8'},
        {'Above the Break 3': '36.9'}
    ],
    'Dallas Mavericks': [
        {'Restricted Area': '67.6'}, {'In the Paint (Non-RA)': '49.4'},
        {'Mid-Range': '42.5'}, {'Left Corner 3': '43.3'},
        {'Right Corner 3': '37.0'}, {'Corner 3': '40.1'},
        {'Above the Break 3': '36.3'}
    ],
    'Denver Nuggets': [
        {'Restricted Area': '70.8'}, {'In the Paint (Non-RA)': '45.6'},
        {'Mid-Range': '39.1'}, {'Left Corner 3': '38.0'},
        {'Right Corner 3': '43.9'}, {'Corner 3': '40.6'},
        {'Above the Break 3': '37.3'}
    ],
    'Detroit Pistons': [
        {'Restricted Area': '64.3'}, {'In the Paint (Non-RA)': '41.7'},
        {'Mid-Range': '41.3'}, {'Left Corner 3': '36.9'},
        {'Right Corner 3': '37.5'}, {'Corner 3': '37.0'},
        {'Above the Break 3': '34.5'}
    ],
    'Golden State Warriors': [
        {'Restricted Area': '70.0'}, {'In the Paint (Non-RA)': '47.5'},
        {'Mid-Range': '41.3'}, {'Left Corner 3': '36.8'},
        {'Right Corner 3': '43.0'}, {'Corner 3': '39.6'},
        {'Above the Break 3': '38.5'}
    ],
    'Houston Rockets': [
        {'Restricted Area': '64.4'}, {'In the Paint (Non-RA)': '37.9'},
        {'Mid-Range': '39.2'}, {'Left Corner 3': '38.0'},
        {'Right Corner 3': '36.8'}, {'Corner 3': '37.3'},
        {'Above the Break 3': '32.1'}
    ],
    'Indiana Pacers': [
        {'Restricted Area': '64.1'}, {'In the Paint (Non-RA)': '42.1'},
        {'Mid-Range': '41.7'}, {'Left Corner 3': '36.6'},
        {'Right Corner 3': '40.2'}, {'Corner 3': '40.4'},
        {'Above the Break 3': '27.9'}
    ],
    'LA Clippers': [
        {'Restricted Area': '64.1'}, {'In the Paint (Non-RA)': '42.9'},
        {'Mid-Range': '41.7'}, {'Left Corner 3': '48.6'},
        {'Right Corner 3': '37.1'}, {'Corner 3': '40.4'},
        {'Above the Break 3': '37.7'}
    ],
    'Los Angeles Lakers': [
        {'Restricted Area': '68.6'}, {'In the Paint (Non-RA)': '43.6'},
        {'Mid-Range': '39.2'}, {'Left Corner 3': '34.5'},
        {'Right Corner 3': '38.4'}, {'Corner 3': '36.4'},
        {'Above the Break 3': '30.0'}
    ],
    'Memphis Grizzlies': [
        {'Restricted Area': '64.2'}, {'In the Paint (Non-RA)': '42.2'},
        {'Mid-Range': '39.3'}, {'Left Corner 3': '36.2'},
        {'Right Corner 3': '34.9'}, {'Corner 3': '35.6'},
        {'Above the Break 3': '34.6'}
    ],
    'Miami Heat': [
        {'Restricted Area': '62.7'}, {'In the Paint (Non-RA)': '40.8'},
        {'Mid-Range': '40.8'}, {'Left Corner 3': '36.2'},
        {'Right Corner 3': '37.8'}, {'Corner 3': '37.0'},
        {'Above the Break 3': '35.6'}
    ],
    'Milwaukee Bucks': [
        {'Restricted Area': '66.4'}, {'In the Paint (Non-RA)': '47.0'},
        {'Mid-Range': '40.1'}, {'Left Corner 3': '37.8'},
        {'Right Corner 3': '35.7'}, {'Corner 3': '37.5'},
        {'Above the Break 3': '35.5'}
    ],
    'Minnesota Timberwolves': [
        {'Restricted Area': '68.1'}, {'In the Paint (Non-RA)': '40.4'},
        {'Mid-Range': '45.0'}, {'Left Corner 3': '41.0'},
        {'Right Corner 3': '37.1'}, {'Corner 3': '38.7'},
        {'Above the Break 3': '36.0'}
    ],
    'New Orleans Pelicans': [
        {'Restricted Area': '66.6'}, {'In the Paint (Non-RA)': '43.5'},
        {'Mid-Range': '39.8'}, {'Left Corner 3': '38.4'},
        {'Right Corner 3': '36.5'}, {'Corner 3': '37.4'},
        {'Above the Break 3': '36.5'}
    ],
    'New York Knicks': [
        {'Restricted Area': '65.1'}, {'In the Paint (Non-RA)': '46.2'},
        {'Mid-Range': '39.5'}, {'Left Corner 3': '40.4'},
        {'Right Corner 3': '35.3'}, {'Corner 3': '37.9'},
        {'Above the Break 3': '34.4'}
    ],
    'Oklahoma City Thunder': [
        {'Restricted Area': '62.5'}, {'In the Paint (Non-RA)': '42.3'},
        {'Mid-Range': '41.8'}, {'Left Corner 3': '38.8'},
        {'Right Corner 3': '41.0'}, {'Corner 3': '39.7'},
        {'Above the Break 3': '34.7'}
    ],
    'Orlando Magic': [
        {'Restricted Area': '66.9'}, {'In the Paint (Non-RA)': '42.7'},
        {'Mid-Range': '39.9'}, {'Left Corner 3': '41.5'},
        {'Right Corner 3': '39.8'}, {'Corner 3': '40.8'},
        {'Above the Break 3': '33.0'}
    ],
    'Philadelphia 76ers': [
        {'Restricted Area': '65.3'}, {'In the Paint (Non-RA)': '44.7'},
        {'Mid-Range': '45.4'}, {'Left Corner 3': '37.6'},
        {'Right Corner 3': '42.5'}, {'Corner 3': '40.0'},
        {'Above the Break 3': '38.5'}
    ],
    'Phoenix Suns': [
        {'Restricted Area': '64.2'}, {'In the Paint (Non-RA)': '41.2'},
        {'Mid-Range': '44.7'}, {'Left Corner 3': '44.0'},
        {'Right Corner 3': '35.2'}, {'Corner 3': '38.1'},
        {'Above the Break 3': '37.1'}
    ],
    'Portland Trail Blazers': [
        {'Restricted Area': '65.0'}, {'In the Paint (Non-RA)': '37.9'},
        {'Mid-Range': '42.3'}, {'Left Corner 3': '40.4'},
        {'Right Corner 3': '31.1'}, {'Corner 3': '37.8'},
        {'Above the Break 3': '36.8'}
    ],
    'Sacramento Kings': [
        {'Restricted Area': '66.0'}, {'In the Paint (Non-RA)': '44.0'},
        {'Mid-Range': '40.7'}, {'Left Corner 3': '41.0'},
        {'Right Corner 3': '38.4'}, {'Corner 3': '39.6'},
        {'Above the Break 3': '34.1'}
    ],
    'San Antonio Spurs': [
        {'Restricted Area': '64.6'}, {'In the Paint (Non-RA)': '43.1'},
        {'Mid-Range': '40.1'}, {'Left Corner 3': '38.5'},
        {'Right Corner 3': '35.7'}, {'Corner 3': '37.2'},
        {'Above the Break 3': '34.0'}
    ],
    'Toronto Raptors': [
        {'Restricted Area': '67.2'}, {'In the Paint (Non-RA)': '47.2'},
        {'Mid-Range': '40.9'}, {'Left Corner 3': '41.5'},
        {'Right Corner 3': '40.9'}, {'Corner 3': '41.2'},
        {'Above the Break 3': '33.7'}
    ],
    'Utah Jazz': [
        {'Restricted Area': '67.2'}, {'In the Paint (Non-RA)': '47.2'},
        {'Mid-Range': '40.9'}, {'Left Corner 3': '41.1'},
        {'Right Corner 3': '41.2'}, {'Corner 3': '40.9'},
        {'Above the Break 3': '32.7'}
    ],
    'Washington Wizards': [
        {'Restricted Area': '72.0'}, {'In the Paint (Non-RA)': '44.2'},
        {'Mid-Range': '44.1'}, {'Left Corner 3': '38.5'},
        {'Right Corner 3': '39.3'}, {'Corner 3': '39.3'},
        {'Above the Break 3': '36.5'}
    ]
}

# %%
import json

# Save the dictionary to a JSON file
with open('config.json', 'w') as f:
    json.dump(stats_dict, f, indent=4)

# %%
teams_ft_percentage = {
    "Milwaukee Bucks": 74.3,
    "Boston Celtics": 81.2,
    "Philadelphia 76ers": 83.5,
    "Denver Nuggets": 75.1,
    "Cleveland Cavaliers": 78.0,
    "Memphis Grizzlies": 73.3,
    "Sacramento Kings": 79.0,
    "New York Knicks": 76.1,
    "Brooklyn Nets": 80.0,
    "Phoenix Suns": 79.3,
    "Golden State Warriors": 79.4,
    "LA Clippers": 78.1,
    "Miami Heat": 83.1,
    "Los Angeles Lakers": 77.5,
    "Minnesota Timberwolves": 75.5,
    "New Orleans Pelicans": 79.3,
    "Atlanta Hawks": 81.8,
    "Toronto Raptors": 78.4,
    "Chicago Bulls": 80.9,
    "Oklahoma City Thunder": 80.9,
    "Dallas Mavericks": 75.5,
    "Utah Jazz": 78.6,
    "Indiana Pacers": 79.0,
    "Washington Wizards": 78.5,
    "Orlando Magic": 78.4,
    "Portland Trail Blazers": 79.6,
    "Charlotte Hornets": 74.9,
    "Houston Rockets": 75.4,
    "San Antonio Spurs": 74.3,
    "Detroit Pistons": 77.1
}

# %%
import json

# Save the dictionary to a JSON file
with open('config_ft.json', 'w') as f:
    json.dump(teams_ft_percentage, f, indent=4)

# %%
import json

# Create the dictionary with team abbreviations and their average possessions per game in 2022
team_possessions = {
    "SAS": 105.8,
    "GSW": 105.6,
    "OKC": 105.3,
    "LAL": 105.0,
    "IND": 105.0,
    "MEM": 105.0,
    "CHA": 104.9,
    "MIN": 104.7,
    "ATL": 104.7,
    "UTA": 104.6,
    "MIL": 104.5,
    "SAC": 104.4,
    "NOP": 103.1,
    "DET": 103.1,
    "ORL": 103.1,
    "HOU": 103.0,
    "CHI": 102.4,
    "BOS": 102.1,
    "POR": 102.1,
    "PHX": 102.1,
    "WAS": 102.0,
    "LAC": 101.8,
    "BKN": 101.3,
    "NYK": 101.2,
    "TOR": 101.1,
    "DAL": 100.9,
    "DEN": 100.8,
    "PHI": 100.4,
    "MIA": 99.6,
    "CLE": 99.5
}

# Convert the dictionary to a JSON format
team_possessions_json = json.dumps(team_possessions, indent=4)

# Save the JSON data to a file
with open('config_pos.json', 'w') as file:
    file.write(team_possessions_json)

print("Data saved to team_possessions.json")
# Out:
# Data saved to team_possessions.json
